# %% [markdown]
# ## Interfacing with Papyrus
#
# The `Papyrus` class is a wrapper around the [Papyrus data set](https://jcheminf.biomedcentral.com/articles/10.1186/s13321-022-00672-x) and its [associated scripts](https://github.com/OlivierBeq/Papyrus-scripts). The class fetches the data set and allows to perform efficient filtering and queries for some common tasks. In this tutorial, we will show how to fetch bioactivity data for a particular set of protein targets.
#
# ### Fetching Bioactivity Data
#
# We can use the following code to fetch bioactivity data for multiple adenosine receptor subtypes at once:

# %%
from qsprpred.data.sources.papyrus import Papyrus

acc_keys = ["P29274", "P29275", "P30542", "P0DMS8"]
dataset_name = "AR_LIGANDS"  # name of the file to be generated
quality = "high"  # choose minimum quality from {"high", "medium", "low"}
papyrus_version = '05.6'  # Papyrus database version
data_dir = "../../tutorial_data/papyrus"

papyrus = Papyrus(
    data_dir=data_dir,
    version=papyrus_version,
    stereo=False,
    plus_only=True,
)

mt = papyrus.getData(
    acc_keys,
    quality,
    name=dataset_name,
    use_existing=True,
    activity_types=["Ki", "IC50", "Kd"]
)
mt.getDF().head()
# Out:
# ########## DISCLAIMER ##########
# You are downloading the high-quality Papyrus++ dataset.
# Should you want to access the entire, though of lower quality, Papyrus dataset,
# look into additional switches of this command.
# ################################
# Number of files to be downloaded: 3
# Total size: 33.0MB
# Downloading version 05.6:   0%|          | 0.00/33.0M [00:00<?, ?B/s]
# Reading data from ../../tutorial_data/papyrus...
# Read all data.
# Initialized filters.
# 0it [00:00, ?it/s]
# Number of compounds:12440
# Wrote data to file '../../tutorial_data/papyrus/AR_LIGANDS.tsv'.
#                               Activity_ID Quality    source  \
# QSPRID
# AR_LIGANDS_0  AACWUFIIMOHGSO_on_P29274_WT    High  ChEMBL31
# AR_LIGANDS_1  AACWUFIIMOHGSO_on_P30542_WT    High  ChEMBL31
# AR_LIGANDS_2  AAEYTMMNWWKSKZ_on_P29274_WT    High  ChEMBL31
# AR_LIGANDS_3  AAGFKZWKWAMJNP_on_P0DMS8_WT    High  ChEMBL31
# AR_LIGANDS_4  AAGFKZWKWAMJNP_on_P29274_WT    High  ChEMBL31
#
#                                    CID  \
# QSPRID
# AR_LIGANDS_0   ChEMBL31.compound.91968
# AR_LIGANDS_1   ChEMBL31.compound.91968
# AR_LIGANDS_2  ChEMBL31.compound.131451
# AR_LIGANDS_3  ChEMBL31.compound.100375
# AR_LIGANDS_4  ChEMBL31.compound.100375
#
#                                                          SMILES  \
# QSPRID
# AR_LIGANDS_0  Cc1nn(-c2cc(NC(=O)CCN(C)C)nc(-c3ccc(C)o3)n2)c(...
# AR_LIGANDS_1  Cc1nn(-c2cc(NC(=O)CCN(C)C)nc(-c3ccc(C)o3)n2)c(...
# AR_LIGANDS_2  Nc1c(C(=O)Nc2ccc([N+](=O)[O-])cc2)sc2c1cc1CCCC...
# AR_LIGANDS_3   O=C(Nc1nc2ncccc2n2c(=O)n(-c3ccccc3)nc12)c1ccccc1
# AR_LIGANDS_4   O=C(Nc1nc2ncccc2n2c(=O)n(-c3ccccc3)nc12)c1ccccc1
#
#                 connectivity                     InChIKey  \
# QSPRID
# AR_LIGANDS_0  AACWUFIIMOHGSO  AACWUFIIMOHGSO-UHFFFAOYSA-N
# AR_LIGANDS_1  AACWUFIIMOHGSO  AACWUFIIMOHGSO-UHFFFAOYSA-N
# AR_LIGANDS_2  AAEYTMMNWWKSKZ  AAEYTMMNWWKSKZ-UHFFFAOYSA-N
# AR_LIGANDS_3  AAGFKZWKWAMJNP  AAGFKZWKWAMJNP-UHFFFAOYSA-N
# AR_LIGANDS_4  AAGFKZWKWAMJNP  AAGFKZWKWAMJNP-UHFFFAOYSA-N
#
#                                                           InChI  \
# QSPRID
# AR_LIGANDS_0  InChI=1S/C19H24N6O2/c1-12-10-13(2)25(23-12)17-...
# AR_LIGANDS_1  InChI=1S/C19H24N6O2/c1-12-10-13(2)25(23-12)17-...
# AR_LIGANDS_2  InChI=1S/C18H16N4O3S/c19-15-13-9-10-3-1-2-4-14...
# AR_LIGANDS_3  InChI=1S/C21H14N6O2/c28-20(14-8-3-1-4-9-14)24-...
# AR_LIGANDS_4  InChI=1S/C21H14N6O2/c28-20(14-8-3-1-4-9-14)24-...
#
#                                                   InChI_AuxInfo  target_id  \
# QSPRID
# AR_LIGANDS_0  "AuxInfo=1/1/N:1,26,22,14,15,20,19,11,12,27,6,...  P29274_WT
# AR_LIGANDS_1  "AuxInfo=1/1/N:1,26,22,14,15,20,19,11,12,27,6,...  P30542_WT
# AR_LIGANDS_2  "AuxInfo=1/1/N:22,23,21,24,8,15,9,14,19,20,7,1...  P29274_WT
# AR_LIGANDS_3  "AuxInfo=1/1/N:27,19,26,28,18,20,9,25,29,17,21...  P0DMS8_WT
# AR_LIGANDS_4  "AuxInfo=1/1/N:27,19,26,28,18,20,9,25,29,17,21...  P29274_WT
#
#               ... Activity_class relation pchembl_value pchembl_value_Mean  \
# QSPRID        ...
# AR_LIGANDS_0  ...            NaN        =          8.68               8.68
# AR_LIGANDS_1  ...            NaN        =          6.68               6.68
# AR_LIGANDS_2  ...            NaN        =          4.82               4.82
# AR_LIGANDS_3  ...            NaN        =          7.15               7.15
# AR_LIGANDS_4  ...            NaN        =          5.65               5.65
#
#              pchembl_value_StdDev  pchembl_value_SEM pchembl_value_N  \
# QSPRID
# AR_LIGANDS_0                  0.0                0.0             1.0
# AR_LIGANDS_1                  0.0                0.0             1.0
# AR_LIGANDS_2                  0.0                0.0             1.0
# AR_LIGANDS_3                  0.0                0.0             1.0
# AR_LIGANDS_4                  0.0                0.0             1.0
#
#              pchembl_value_Median pchembl_value_MAD        QSPRID
# QSPRID
# AR_LIGANDS_0                 8.68               0.0  AR_LIGANDS_0
# AR_LIGANDS_1                 6.68               0.0  AR_LIGANDS_1
# AR_LIGANDS_2                 4.82               0.0  AR_LIGANDS_2
# AR_LIGANDS_3                 7.15               0.0  AR_LIGANDS_3
# AR_LIGANDS_4                 5.65               0.0  AR_LIGANDS_4
#
# [5 rows x 33 columns]

# %% [markdown]
# By default, the method returns a `MoleculeTable` so if you want to turn it into a `QSPRDataset` for modeling, you have to use the `fromMolTable` helper method. See the basic [data representation tutorial](data_representation.ipynb) for more details.

# %%
from qsprpred.models.tasks import TargetTasks
from qsprpred.data.data import QSPRDataset

target_props=[{"name": "pchembl_value_Median", "task": TargetTasks.SINGLECLASS, "th": [6.5]}]
ds = QSPRDataset.fromMolTable(mt, target_props=target_props)
ds.targetProperties
# Out:
# [TargetProperty(name=pchembl_value_Median_class, task=SINGLECLASS, th=[6.5])]
