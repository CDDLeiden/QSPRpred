# %% [markdown]
# # Descriptor calculation
# This tutorial provides an overview of the descriptors that can be calculated with QSPRpred.
#
# First, we will import the necessary modules and load the dataset that we will use for this tutorial.

# %%
import os
from qsprpred.data.data import MoleculeTable

os.makedirs("../../tutorial_output/data", exist_ok=True)

dataset = MoleculeTable.fromTableFile(
  	filename='../../tutorial_data/A2A_LIGANDS.tsv',
  	store_dir="../../tutorial_output/data",
  	name="DescriptorsTutorialDataset",
)

dataset.getDF()
# Out:
#                                                                             SMILES  \
# QSPRID
# DescriptorsTutorialDataset_0     Cc1nn(-c2cc(NC(=O)CCN(C)C)nc(-c3ccc(C)o3)n2)c(...
# DescriptorsTutorialDataset_1     Nc1c(C(=O)Nc2ccc([N+](=O)[O-])cc2)sc2c1cc1CCCC...
# DescriptorsTutorialDataset_2      O=C(Nc1nc2ncccc2n2c(=O)n(-c3ccccc3)nc12)c1ccccc1
# DescriptorsTutorialDataset_3     CNC(=O)C12CC1C(n1cnc3c1nc(C#CCCCCC(=O)OC)nc3NC...
# DescriptorsTutorialDataset_4     CCCn1c(=O)c2c(nc3cc(OC)ccn32)n(CCCNC(=O)c2ccc(...
# ...                                                                            ...
# DescriptorsTutorialDataset_4077     CNc1ncc(C(=O)NCc2ccc(OC)cc2)c2nc(-c3ccco3)nn12
# DescriptorsTutorialDataset_4078         Nc1nc(-c2ccco2)c2ncn(C(=O)NCCc3ccccc3)c2n1
# DescriptorsTutorialDataset_4079              Nc1nc(Nc2ccc(F)cc2)nc(CSc2nnc(N)s2)n1
# DescriptorsTutorialDataset_4080      CCCOc1ccc(C=Cc2cc3c(c(=O)n(C)c(=O)n3C)n2C)cc1
# DescriptorsTutorialDataset_4081           CCOC(=O)c1cnc(NCC(C)C)n2nc(-c3ccco3)nc12
#
#                                  pchembl_value_Mean    Year  \
# QSPRID
# DescriptorsTutorialDataset_0                   8.68  2008.0
# DescriptorsTutorialDataset_1                   4.82  2010.0
# DescriptorsTutorialDataset_2                   5.65  2009.0
# DescriptorsTutorialDataset_3                   5.45  2009.0
# DescriptorsTutorialDataset_4                   5.20  2019.0
# ...                                             ...     ...
# DescriptorsTutorialDataset_4077                7.09  2018.0
# DescriptorsTutorialDataset_4078                8.22  2008.0
# DescriptorsTutorialDataset_4079                4.89  2010.0
# DescriptorsTutorialDataset_4080                6.51  2013.0
# DescriptorsTutorialDataset_4081                7.35  2014.0
#
#                                                           QSPRID
# QSPRID
# DescriptorsTutorialDataset_0        DescriptorsTutorialDataset_0
# DescriptorsTutorialDataset_1        DescriptorsTutorialDataset_1
# DescriptorsTutorialDataset_2        DescriptorsTutorialDataset_2
# DescriptorsTutorialDataset_3        DescriptorsTutorialDataset_3
# DescriptorsTutorialDataset_4        DescriptorsTutorialDataset_4
# ...                                                          ...
# DescriptorsTutorialDataset_4077  DescriptorsTutorialDataset_4077
# DescriptorsTutorialDataset_4078  DescriptorsTutorialDataset_4078
# DescriptorsTutorialDataset_4079  DescriptorsTutorialDataset_4079
# DescriptorsTutorialDataset_4080  DescriptorsTutorialDataset_4080
# DescriptorsTutorialDataset_4081  DescriptorsTutorialDataset_4081
#
# [4082 rows x 4 columns]

# %% [markdown]
# ## Fingerprints
