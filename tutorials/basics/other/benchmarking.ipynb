# %% [markdown]
# # Benchmarking QSPR Models and More
#
# The `qsprpred.benchmarks` module provides a set of functions to compare machine learning algorithms, preparation steps, hyperparameter optimization strategies, molecular descriptors and more on various data sets that are already prepared or of your own choosing. In this tutorial, we will provide a simple example to benchmark a selection of models and descriptors on a simple task using one of the data sets provided with this tutorial.
#
# ## Choosing the Data Set
#
# The first step is to decide, which data set(s) to use for your benchmark. To make things a little faster, we will write a custom data source that will sample a smaller benchmarking set from our tutorial data set:

# %%
import os

import pandas as pd

from qsprpred.data import MoleculeTable
from qsprpred.data.sources import DataSource

BASE_DIR = "../../tutorial_output/benchmarking"  # directory to store all benchmarking results and files
os.makedirs(BASE_DIR, exist_ok=True)  # make sure it exists
SEED = 42  # random seed for all random operations, you should always get the same results with the same settings


class DataSourceTesting(DataSource):
    """
    Just a simple wrapper around our tutorial data set.
    """

    def __init__(self, name: str, base_dir: str):
        self.name = name  # name of the created data set
        self.baseDir = base_dir  # where to save it and all its derived data sets

    def getData(self, name: str | None = None, **kwargs) -> MoleculeTable:
        """We just need to create a simple `MoleculeTable` here.
        Defining target properties is not necessary at thist point 
        because they will be set as part of the benchmark paremetrization. 
        To make things faster we will also sample only 100 molecules.
        Note that this method could also provide different data sets
        based on the `self.name` or other parameters. It also does not
        include descriptors, which are added as required creating derived
        data sets in `self.baseDir`.
        """
        name = name or self.name
        return MoleculeTable.fromDF(
            df=pd.read_table('../../tutorial_data/A2A_LIGANDS.tsv').sample(
                100,
                random_state=SEED
            ),  # source data frame
            name=name,  # 
            path=self.baseDir,
            **kwargs
        )


source = DataSourceTesting("TutorialBenchmarkData", f"{BASE_DIR}/data")
example_ds = source.getData()
example_ds.getDF()

# %% [markdown]
# You can wrap your own data set in a `DataSource` class to use it for benchmarking. Just implement the `qsprpred.data.sources.data_source.DataSource` interface. Just make sure it containes properties that you specify as the `TargetProperty` later in the workflow.
#
# Next thing to do is to decide the benchmarking settings. You will use the `BenchmarkSettings` class to specify all details of your benchmark:

# %%
from qsprpred.data.descriptors.fingerprints import MorganFP
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.naive_bayes import GaussianNB
from qsprpred.models import SklearnModel, Assessor
from qsprpred.data.processing.feature_filters import LowVarianceFilter
from sklearn.preprocessing import StandardScaler
from qsprpred.data import RandomSplit, ClusterSplit
from qsprpred import TargetSpec, TargetTasks
from qsprpred.data.descriptors.sets import RDKitDescs
from qsprpred.benchmarks import BenchmarkSettings
from qsprpred.data import DatasetPipeline

settings = BenchmarkSettings(
    name="TutorialBenchmark",
    n_replicas=3,
    # number of repeated experiments for statistical power, just 3 here for faster calculations
    random_seed=SEED,  # random seed for all random operations
    data_sources=[
        # one or more data sources to use for benchmarking
        source  # we defined this one above
    ],
    descriptors=[
        # in this case we will test 3 different combinations of descriptors
        [
            MorganFP(radius=2, nBits=256),
            RDKitDescs()
        ],
        [
            MorganFP(radius=2, nBits=256)
        ],
        [
            RDKitDescs()
        ]
    ],
    target_props=[
        # one or more properties to model, the table from our data source must contain them
        [
            TargetSpec.fromDict(
                {
                    "name": "pchembl_value_Mean",
                    "task": TargetTasks.SINGLECLASS,
                    "th": [6.5]
                }
            )
        ],
    ],
    pipelines=[
        # The preprocessing steps to apply to the data set before modeling
        DatasetPipeline(
            steps={
                "filter": LowVarianceFilter(0.05),
                "scaler": StandardScaler()
            }
        ),
    ],
    # we will compare two splitting strategies
    assessors=[
        Assessor(
            name="randomsplit_roc_auc",
            scoring="roc_auc",
            split=RandomSplit(test_fraction=0.2),  # random split
        ),
        Assessor(
            name="randomsplit_matthews_corrcoef",
            scoring="matthews_corrcoef",
            split=RandomSplit(test_fraction=0.2),  # random split
            use_proba=False
        ),
        Assessor(
            name="clustersplit_roc_auc",
            scoring="roc_auc",
            split=ClusterSplit(test_fraction=0.2),  # cluster split
        ),
        Assessor(
            name="clustersplit_matthews_corrcoef",
            scoring="matthews_corrcoef",
            split=ClusterSplit(test_fraction=0.2),  # cluster split
            use_proba=False
        )
    ],
    models=[
        # the algorithms to benchmarks, this can be any implementation of `QSPRModel`
        SklearnModel(
            name="GaussianNB",
            alg=GaussianNB,
            base_dir=f"{BASE_DIR}/models",
        ),
        SklearnModel(
            name="ExtraTreesClassifier",
            alg=ExtraTreesClassifier,
            base_dir=f"{BASE_DIR}/models",
        )
    ]
)

# %% [markdown]
# These settings can be saved and reloaded as needed in the JSON format:

# %%
BenchmarkSettings.fromFile(settings.toFile(f"{BASE_DIR}/settings.json"))
# Out:
# BenchmarkSettings(name='TutorialBenchmark', n_replicas=3, random_seed=42, data_sources=[<__main__.DataSourceTesting object at 0x7fa943b95390>], descriptors=[[<qsprpred.data.descriptors.fingerprints.MorganFP object at 0x7fa943b95490>, <qsprpred.data.descriptors.sets.RDKitDescs object at 0x7fa943b95510>], [<qsprpred.data.descriptors.fingerprints.MorganFP object at 0x7fa943b95450>], [<qsprpred.data.descriptors.sets.RDKitDescs object at 0x7fa943b957d0>]], target_props=[[TargetProperty(name=pchembl_value_Mean, task=SINGLECLASS, th=[6.5])]], pipelines=[<qsprpred.data.processing.pipeline.DatasetPipeline object at 0x7fa943b95a90>], models=[<qsprpred.models.scikit_learn.SklearnModel object at 0x7fa943b1cd90>, <qsprpred.models.scikit_learn.SklearnModel object at 0x7fa943b1d1d0>], assessors=[<qsprpred.models.assessment.methods.Assessor object at 0x7fa943b95ed0>, <qsprpred.models.assessment.methods.Assessor object at 0x7fa943b959d0>, <qsprpred.models.assessment.methods.Assessor object at 0x7fa943b95f10>, <qsprpred.models.assessment.methods.Assessor object at 0x7fa943b96290>], subsets=(), optimizers=())

# %% [markdown]
# The settings can then be used to instantiate a runner that handles the creation of different replicas and data sets with the appropriate descriptors:

# %%
from qsprpred.benchmarks import BenchmarkRunner

runner = BenchmarkRunner(
    settings,  # our settings
    data_dir=BASE_DIR  # where to save outputs
)

# %% [markdown]
# To get an idea on computational complexity, we can check how many replicas we will run:

# %%
runner.nRuns
# Out:
# 18

# %% [markdown]
# This is the number of all modeling workflows that the runner will execute. We can check the details of each one by iterating over the replicas:

# %%
for replica in runner.iterReplicas():
    # replicas contain all info needed to run an experiment
    print(replica)
    print(replica.dataSource.name)
    print(replica.descriptors)
    print(replica.targetProps)
    print(replica.assessors)
    break  # only show the first replica
# Out:
# TutorialBenchmark_478163327
# TutorialBenchmarkData
# [<qsprpred.data.descriptors.fingerprints.MorganFP object at 0x7fa943d6bb90>, <qsprpred.data.descriptors.sets.RDKitDescs object at 0x7fa943f33f90>]
# [TargetProperty(name=pchembl_value_Mean, task=SINGLECLASS, th=[6.5])]
# [<qsprpred.models.assessment.methods.Assessor object at 0x7fa943bf0a90>, <qsprpred.models.assessment.methods.Assessor object at 0x7fa943bf2dd0>, <qsprpred.models.assessment.methods.Assessor object at 0x7fa943bf3210>, <qsprpred.models.assessment.methods.Assessor object at 0x7fa943c0d090>]

# %% [markdown]
# Replicas also have methods to perform different stages of an experiment, but the runner executes them in order for us and also distributes the calculations over the available CPUs:

# %%
import shutil

if os.path.exists(BASE_DIR):
    # start fresh (not needed if you want to reuse results from the previous runs)
    shutil.rmtree(BASE_DIR, ignore_errors=True)

# this will start the actual benchmarking
runner.run(raise_errors=True)  # the runner will not continue if an error is raised
# Out:
# TutorialBenchmark_478163327 - DEBUG - Starting replica: TutorialBenchmark_478163327
# TutorialBenchmark_478163327 - DEBUG - Checking TutorialBenchmark_478163327 in results file: ../../tutorial_output/benchmarking/results.tsv
# TutorialBenchmark_478163327 - DEBUG - Initializing data...
# TutorialBenchmark_478163327 - DEBUG - Initializing data set...
# TutorialBenchmark_478163327 - DEBUG - Done.
# TutorialBenchmark_478163327 - DEBUG - Adding descriptors...
# TutorialBenchmark_107420369 - DEBUG - Starting replica: TutorialBenchmark_107420369
# TutorialBenchmark_1181241943 - DEBUG - Starting replica: TutorialBenchmark_1181241943
# TutorialBenchmark_1051802512 - DEBUG - Starting replica: TutorialBenchmark_1051802512
# TutorialBenchmark_958682846 - DEBUG - Starting replica: TutorialBenchmark_958682846
# TutorialBenchmark_599310825 - DEBUG - Starting replica: TutorialBenchmark_599310825
# TutorialBenchmark_440213415 - DEBUG - Starting replica: TutorialBenchmark_440213415
# TutorialBenchmark_373399426 - DEBUG - Starting replica: TutorialBenchmark_373399426
# TutorialBenchmark_1812140441 - DEBUG - Starting replica: TutorialBenchmark_1812140441
# TutorialBenchmark_136505587 - DEBUG - Starting replica: TutorialBenchmark_136505587
# TutorialBenchmark_127978094 - DEBUG - Starting replica: TutorialBenchmark_127978094
# TutorialBenchmark_402418010 - DEBUG - Starting replica: TutorialBenchmark_402418010
# TutorialBenchmark_939042955 - DEBUG - Starting replica: TutorialBenchmark_939042955
# TutorialBenchmark_999270936 - DEBUG - Starting replica: TutorialBenchmark_999270936
# TutorialBenchmark_113971123 - DEBUG - Starting replica: TutorialBenchmark_113971123
# TutorialBenchmark_854001193 - DEBUG - Starting replica: TutorialBenchmark_854001193
# TutorialBenchmark_1801823908 - DEBUG - Starting replica: TutorialBenchmark_1801823908
# TutorialBenchmark_946785248 - DEBUG - Starting replica: TutorialBenchmark_946785248
# TutorialBenchmark_478163327 - DEBUG - Done.
# TutorialBenchmark_478163327 - DEBUG - Done.
# TutorialBenchmark_478163327 - DEBUG - Done.
# TutorialBenchmark_107420369 - DEBUG - Checking TutorialBenchmark_107420369 in results file: ../../tutorial_output/benchmarking/results.tsv
# TutorialBenchmark
- DEBUG - Adding report to: ../../tutorial_output/benchmarking/results.tsv
# TutorialBenchmark_136505587 - DEBUG - Done.
# TutorialBenchmark_136505587 - DEBUG - Finished replica: TutorialBenchmark_136505587
# TutorialBenchmark_402418010 - DEBUG - Done.
# TutorialBenchmark_402418010 - DEBUG - Creating report...
# TutorialBenchmark_999270936 - DEBUG - Done.
# TutorialBenchmark_999270936 - DEBUG - Adding report to: ../../tutorial_output/benchmarking/results.tsv
# TutorialBenchmark_999270936 - DEBUG - Done.
# TutorialBenchmark_999270936 - DEBUG - Finished replica: TutorialBenchmark_999270936
# TutorialBenchmark_402418010 - DEBUG - Done.
# TutorialBenchmark_402418010 - DEBUG - Adding report to: ../../tutorial_output/benchmarking/results.tsv
# TutorialBenchmark_402418010 - DEBUG - Done.
# TutorialBenchmark_402418010 - DEBUG - Finished replica: TutorialBenchmark_402418010
# TutorialBenchmark_854001193 - DEBUG - Done.
# TutorialBenchmark_854001193 - DEBUG - Creating report...
# TutorialBenchmark_854001193 - DEBUG - Done.
# TutorialBenchmark_854001193 - DEBUG - Adding report to: ../../tutorial_output/benchmarking/results.tsv
# TutorialBenchmark_854001193 - DEBUG - Done.
# TutorialBenchmark_854001193 - DEBUG - Finished replica: TutorialBenchmark_854001193
# TutorialBenchmark_1812140441 - DEBUG - Done.
# TutorialBenchmark_1812140441 - DEBUG - Creating report...
# TutorialBenchmark_1812140441 - DEBUG - Done.
# TutorialBenchmark_1812140441 - DEBUG - Adding report to: ../../tutorial_output/benchmarking/results.tsv
# TutorialBenchmark_1812140441 - DEBUG - Done.
# TutorialBenchmark_1812140441 - DEBUG - Finished replica: TutorialBenchmark_1812140441
# TutorialBenchmark_946785248 - DEBUG - Done.
# TutorialBenchmark_946785248 - DEBUG - Creating report...
# TutorialBenchmark_946785248 - DEBUG - Done.
# TutorialBenchmark_946785248 - DEBUG - Adding report to: ../../tutorial_output/benchmarking/results.tsv
# TutorialBenchmark_946785248 - DEBUG - Done.
# TutorialBenchmark_946785248 - DEBUG - Finished replica: TutorialBenchmark_946785248
#                           Assessor          ScoreFunc     Score  \
# 0              randomsplit_roc_auc      roc_auc_score  0.521978
# 1    randomsplit_matthews_corrcoef  matthews_corrcoef  0.104828
# 2             clustersplit_roc_auc      roc_auc_score  0.625000
# 3   clustersplit_matthews_corrcoef  matthews_corrcoef  0.123091
# 4              randomsplit_roc_auc      roc_auc_score  0.757576
# ..                             ...                ...       ...
# 67  clustersplit_matthews_corrcoef  matthews_corrcoef  0.301511
# 68             randomsplit_roc_auc      roc_auc_score  0.802198
# 69   randomsplit_matthews_corrcoef  matthews_corrcoef  0.560440
# 70            clustersplit_roc_auc      roc_auc_score  0.388889
# 71  clustersplit_matthews_corrcoef  matthews_corrcoef -0.242320
#
#         TargetProperty   TargetTask  \
# 0   pchembl_value_Mean  SINGLECLASS
# 1   pchembl_value_Mean  SINGLECLASS
# 2   pchembl_value_Mean  SINGLECLASS
# 3   pchembl_value_Mean  SINGLECLASS
# 4   pchembl_value_Mean  SINGLECLASS
# ..                 ...          ...
# 67  pchembl_value_Mean  SINGLECLASS
# 68  pchembl_value_Mean  SINGLECLASS
# 69  pchembl_value_Mean  SINGLECLASS
# 70  pchembl_value_Mean  SINGLECLASS
# 71  pchembl_value_Mean  SINGLECLASS
#
#                                             ModelFile             Algorithm  \
# 0   /zfsdata/data/helle/01_MainProjects/03_QSPRpre...            GaussianNB
# 1   /zfsdata/data/helle/01_MainProjects/03_QSPRpre...            GaussianNB
# 2   /zfsdata/data/helle/01_MainProjects/03_QSPRpre...            GaussianNB
# 3   /zfsdata/data/helle/01_MainProjects/03_QSPRpre...            GaussianNB
# 4   /zfsdata/data/helle/01_MainProjects/03_QSPRpre...            GaussianNB
# ..                                                ...                   ...
# 67  /zfsdata/data/helle/01_MainProjects/03_QSPRpre...            GaussianNB
# 68  /zfsdata/data/helle/01_MainProjects/03_QSPRpre...  ExtraTreesClassifier
# 69  /zfsdata/data/helle/01_MainProjects/03_QSPRpre...  ExtraTreesClassifier
# 70  /zfsdata/data/helle/01_MainProjects/03_QSPRpre...  ExtraTreesClassifier
# 71  /zfsdata/data/helle/01_MainProjects/03_QSPRpre...  ExtraTreesClassifier
#
#                 AlgorithmParams                     ReplicaID  \
# 0                           NaN   TutorialBenchmark_478163327
# 1                           NaN   TutorialBenchmark_478163327
# 2                           NaN   TutorialBenchmark_478163327
# 3                           NaN   TutorialBenchmark_478163327
# 4                           NaN  TutorialBenchmark_1181241943
# ..                          ...                           ...
# 67                          NaN  TutorialBenchmark_1812140441
# 68  {"random_state": 946785248}   TutorialBenchmark_946785248
# 69  {"random_state": 946785248}   TutorialBenchmark_946785248
# 70  {"random_state": 946785248}   TutorialBenchmark_946785248
# 71  {"random_state": 946785248}   TutorialBenchmark_946785248
#
#                                  DataSet  \
# 0   TutorialBenchmarkData_MorganFP_RDkit
# 1   TutorialBenchmarkData_MorganFP_RDkit
# 2   TutorialBenchmarkData_MorganFP_RDkit
# 3   TutorialBenchmarkData_MorganFP_RDkit
# 4         TutorialBenchmarkData_MorganFP
# ..                                   ...
# 67        TutorialBenchmarkData_MorganFP
# 68           TutorialBenchmarkData_RDkit
# 69           TutorialBenchmarkData_RDkit
# 70           TutorialBenchmarkData_RDkit
# 71           TutorialBenchmarkData_RDkit
#
#                                           ReplicaFile
# 0   /zfsdata/data/helle/01_MainProjects/03_QSPRpre...
# 1   /zfsdata/data/helle/01_MainProjects/03_QSPRpre...
# 2   /zfsdata/data/helle/01_MainProjects/03_QSPRpre...
# 3   /zfsdata/data/helle/01_MainProjects/03_QSPRpre...
# 4   /zfsdata/data/helle/01_MainProjects/03_QSPRpre...
# ..                                                ...
# 67  /zfsdata/data/helle/01_MainProjects/03_QSPRpre...
# 68  /zfsdata/data/helle/01_MainProjects/03_QSPRpre...
# 69  /zfsdata/data/helle/01_MainProjects/03_QSPRpre...
# 70  /zfsdata/data/helle/01_MainProjects/03_QSPRpre...
# 71  /zfsdata/data/helle/01_MainProjects/03_QSPRpre...
#
# [72 rows x 11 columns]

# %% [markdown]
# **Note on reusing results:** It is recommended to reuse results only when the settings of the runner have not changed. If they did, you might be running a risk of reusing irrelevant results because the same ID can be generated for a replica that defines a different experiment in the new settings. Since this tutorial is for experimentation, we remmove the entire result directory (`BASE_DIR`) and start fresh each time. But you could also leave your results in place and the runner will continue from the last unfinished replica, but beware of the danger above when settings are changed.
#
# When the runner has finished we can load the results of our benchmark. It is a simple data frame:

# %%
df_results = pd.read_table(runner.resultsFile)
df_results.shape
# Out:
# (72, 11)

# %% [markdown]
# It is 4 times the number of replicas because we have four assessors:

# %%
4 * runner.nRuns
# Out:
# 72

# %% [markdown]
# We can check the results for the first replica:

# %%
df_results.iloc[0, :]
# Out:
# Assessor                                         randomsplit_roc_auc
# ScoreFunc                                              roc_auc_score
# Score                                                       0.521978
# TargetProperty                                    pchembl_value_Mean
# TargetTask                                               SINGLECLASS
# ModelFile          /zfsdata/data/helle/01_MainProjects/03_QSPRpre...
# Algorithm                                                 GaussianNB
# AlgorithmParams                                                  NaN
# ReplicaID                                TutorialBenchmark_478163327
# DataSet                         TutorialBenchmarkData_MorganFP_RDkit
# ReplicaFile        /zfsdata/data/helle/01_MainProjects/03_QSPRpre...
# Name: 0, dtype: object

# %% [markdown]
# We can see that for this replica we were testing the `GaussianNB` model with the `CL` property and the `RandomSplit` strategy. We can also see the `roc_auc_score` metric was measured here and its value is in the `Score` column. Note the `ReplicaFile` property as well, which we can always use to recreate the replica instance:

# %%
from qsprpred.benchmarks import Replica

replica = Replica.fromFile(df_results.iloc[0, :].ReplicaFile)
replica

# %% [markdown]
# # Recreating Experiments
#
# QSPRpred aims for maximum reproducibility of experiments. Therefore, each replica can be rerun after saving and experiments repeated:

# %%
# reinitialize data
replica.initData()

# %%
replica.ds.getDF()
# Out:
#                                                                                       SMILES  \
# ID
# TutorialBenchmarkData_storage_library_000                CCCn1c(-c2ccccc2)nc2c1ncnc2NC1CCOC1
# TutorialBenchmarkData_storage_library_001      CCCn1c(=O)c2c([nH]c(-c3c[nH]nc3)n2)n(CCC)c1=O
# TutorialBenchmarkData_storage_library_002  COc1cccc2c1nc(N)n1nc(CN3CCN(c4ncc(F)cc4)CC3C)nc21
# TutorialBenchmarkData_storage_library_003          COc1cccc(CCCC(=O)Nc2nc3c(cccc3)c(=O)s2)c1
# TutorialBenchmarkData_storage_library_004   COc1c2nc(NC(=O)c3ccc(F)cc3)sc2c(N(CCO)C(C)=O)cc1
# ...                                                                                      ...
# TutorialBenchmarkData_storage_library_095                 Cc1ccc2c(O)c(C(=O)NCc3ccco3)cnc2n1
# TutorialBenchmarkData_storage_library_096               CC(O)CCc1nc(N)c2nc(-n3nccn3)n(C)c2n1
# TutorialBenchmarkData_storage_library_097    CCN(C(C)=O)c1ccc(Cl)c2c1sc(NC(=O)c1ccc(F)cc1)n2
# TutorialBenchmarkData_storage_library_098      CS(=O)(=O)c1ccc(Cn2ncc3c2nc(N)nc3-c2ccco2)cc1
# TutorialBenchmarkData_storage_library_099          N#Cc1c(-c2cc3c(cc2)OCO3)nc(N)nc1-c1ccccc1
#
#                                            pchembl_value_Mean    Year  \
# ID
# TutorialBenchmarkData_storage_library_000               False  2018.0
# TutorialBenchmarkData_storage_library_001                True  2006.0
# TutorialBenchmarkData_storage_library_002                True  2015.0
# TutorialBenchmarkData_storage_library_003                True  2013.0
# TutorialBenchmarkData_storage_library_004                True  2010.0
# ...                                                       ...     ...
# TutorialBenchmarkData_storage_library_095                True  2005.0
# TutorialBenchmarkData_storage_library_096                True  2013.0
# TutorialBenchmarkData_storage_library_097                True  2010.0
# TutorialBenchmarkData_storage_library_098               False  2008.0
# TutorialBenchmarkData_storage_library_099                True  2008.0
#
#                                                                              original_smiles  \
# ID
# TutorialBenchmarkData_storage_library_000                CCCn1c(-c2ccccc2)nc2c1ncnc2NC1CCOC1
# TutorialBenchmarkData_storage_library_001      CCCn1c(=O)c2c([nH]c(-c3c[nH]nc3)n2)n(CCC)c1=O
# TutorialBenchmarkData_storage_library_002  COc1cccc2c1nc(N)n1nc(CN3CCN(c4ncc(F)cc4)CC3C)nc21
# TutorialBenchmarkData_storage_library_003          COc1cccc(CCCC(=O)Nc2nc3c(cccc3)c(=O)s2)c1
# TutorialBenchmarkData_storage_library_004   COc1c2nc(NC(=O)c3ccc(F)cc3)sc2c(N(CCO)C(C)=O)cc1
# ...                                                                                      ...
# TutorialBenchmarkData_storage_library_095                 Cc1ccc2c(O)c(C(=O)NCc3ccco3)cnc2n1
# TutorialBenchmarkData_storage_library_096               CC(O)CCc1nc(N)c2nc(-n3nccn3)n(C)c2n1
# TutorialBenchmarkData_storage_library_097    CCN(C(C)=O)c1ccc(Cl)c2c1sc(NC(=O)c1ccc(F)cc1)n2
# TutorialBenchmarkData_storage_library_098      CS(=O)(=O)c1ccc(Cn2ncc3c2nc(N)nc3-c2ccco2)cc1
# TutorialBenchmarkData_storage_library_099          N#Cc1c(-c2cc3c(cc2)OCO3)nc(N)nc1-c1ccccc1
#
#                                                                                   ID  \
# ID
# TutorialBenchmarkData_storage_library_000  TutorialBenchmarkData_storage_library_000
# TutorialBenchmarkData_storage_library_001  TutorialBenchmarkData_storage_library_001
# TutorialBenchmarkData_storage_library_002  TutorialBenchmarkData_storage_library_002
# TutorialBenchmarkData_storage_library_003  TutorialBenchmarkData_storage_library_003
# TutorialBenchmarkData_storage_library_004  TutorialBenchmarkData_storage_library_004
# ...                                                                              ...
# TutorialBenchmarkData_storage_library_095  TutorialBenchmarkData_storage_library_095
# TutorialBenchmarkData_storage_library_096  TutorialBenchmarkData_storage_library_096
# TutorialBenchmarkData_storage_library_097  TutorialBenchmarkData_storage_library_097
# TutorialBenchmarkData_storage_library_098  TutorialBenchmarkData_storage_library_098
# TutorialBenchmarkData_storage_library_099  TutorialBenchmarkData_storage_library_099
#
#                                                                     ID_before_change  \
# ID
# TutorialBenchmarkData_storage_library_000  TutorialBenchmarkData_storage_library_000
# TutorialBenchmarkData_storage_library_001  TutorialBenchmarkData_storage_library_001
# TutorialBenchmarkData_storage_library_002  TutorialBenchmarkData_storage_library_002
# TutorialBenchmarkData_storage_library_003  TutorialBenchmarkData_storage_library_003
# TutorialBenchmarkData_storage_library_004  TutorialBenchmarkData_storage_library_004
# ...                                                                              ...
# TutorialBenchmarkData_storage_library_095  TutorialBenchmarkData_storage_library_095
# TutorialBenchmarkData_storage_library_096  TutorialBenchmarkData_storage_library_096
# TutorialBenchmarkData_storage_library_097  TutorialBenchmarkData_storage_library_097
# TutorialBenchmarkData_storage_library_098  TutorialBenchmarkData_storage_library_098
# TutorialBenchmarkData_storage_library_099  TutorialBenchmarkData_storage_library_099
#
#                                            pchembl_value_Mean_original
# ID
# TutorialBenchmarkData_storage_library_000                        5.770
# TutorialBenchmarkData_storage_library_001                        6.640
# TutorialBenchmarkData_storage_library_002                        7.880
# TutorialBenchmarkData_storage_library_003                        6.940
# TutorialBenchmarkData_storage_library_004                        7.010
# ...                                                                ...
# TutorialBenchmarkData_storage_library_095                        7.460
# TutorialBenchmarkData_storage_library_096                        7.102
# TutorialBenchmarkData_storage_library_097                        7.820
# TutorialBenchmarkData_storage_library_098                        6.470
# TutorialBenchmarkData_storage_library_099                        8.280
#
# [100 rows x 7 columns]

# %%
# reinitialize descriptors
replica.addDescriptors()

# %%
replica.ds.getDescriptors()
# Out:
#                                            MorganFP_MorganFP_0  \
# ID
# TutorialBenchmarkData_storage_library_000                False
# TutorialBenchmarkData_storage_library_001                False
# TutorialBenchmarkData_storage_library_002                 True
# TutorialBenchmarkData_storage_library_003                 True
# TutorialBenchmarkData_storage_library_004                 True
# ...                                                        ...
# TutorialBenchmarkData_storage_library_095                False
# TutorialBenchmarkData_storage_library_096                False
# TutorialBenchmarkData_storage_library_097                False
# TutorialBenchmarkData_storage_library_098                False
# TutorialBenchmarkData_storage_library_099                False
#
#                                            MorganFP_MorganFP_1  \
# ID
# TutorialBenchmarkData_storage_library_000                False
# TutorialBenchmarkData_storage_library_001                False
# TutorialBenchmarkData_storage_library_002                False
# TutorialBenchmarkData_storage_library_003                False
# TutorialBenchmarkData_storage_library_004                False
# ...                                                        ...
# TutorialBenchmarkData_storage_library_095                False
# TutorialBenchmarkData_storage_library_096                 True
# TutorialBenchmarkData_storage_library_097                False
# TutorialBenchmarkData_storage_library_098                False
# TutorialBenchmarkData_storage_library_099                False
#
#                                            MorganFP_MorganFP_2  \
# ID
# TutorialBenchmarkData_storage_library_000                False
# TutorialBenchmarkData_storage_library_001                False
# TutorialBenchmarkData_storage_library_002                False
# TutorialBenchmarkData_storage_library_003                False
# TutorialBenchmarkData_storage_library_004                False
# ...                                                        ...
# TutorialBenchmarkData_storage_library_095                False
# TutorialBenchmarkData_storage_library_096                False
# TutorialBenchmarkData_storage_library_097                False
# TutorialBenchmarkData_storage_library_098                False
# TutorialBenchmarkData_storage_library_099                False
#
#                                            MorganFP_MorganFP_3  \
# ID
# TutorialBenchmarkData_storage_library_000                False
# TutorialBenchmarkData_storage_library_001                 True
# TutorialBenchmarkData_storage_library_002                False
# TutorialBenchmarkData_storage_library_003                False
# TutorialBenchmarkData_storage_library_004                False
# ...                                                        ...
# TutorialBenchmarkData_storage_library_095                False
# TutorialBenchmarkData_storage_library_096                False
# TutorialBenchmarkData_storage_library_097                False
# TutorialBenchmarkData_storage_library_098                False
# TutorialBenchmarkData_storage_library_099                False
#
#                                            MorganFP_MorganFP_4  \
# ID
# TutorialBenchmarkData_storage_library_000                False
# TutorialBenchmarkData_storage_library_001                False
# TutorialBenchmarkData_storage_library_002                False
# TutorialBenchmarkData_storage_library_003                False
# TutorialBenchmarkData_storage_library_004                False
# ...                                                        ...
# TutorialBenchmarkData_storage_library_095                False
# TutorialBenchmarkData_storage_library_096                False
# TutorialBenchmarkData_storage_library_097                False
# TutorialBenchmarkData_storage_library_098                False
# TutorialBenchmarkData_storage_library_099                False
#
#                                            MorganFP_MorganFP_5  \
# ID
# TutorialBenchmarkData_storage_library_000                False
# TutorialBenchmarkData_storage_library_001                False
# TutorialBenchmarkData_storage_library_002                False
# TutorialBenchmarkData_storage_library_003                False
# TutorialBenchmarkData_storage_library_004                False
# ...                                                        ...
# TutorialBenchmarkData_storage_library_095                False
# TutorialBenchmarkData_storage_library_096                False
# TutorialBenchmarkData_storage_library_097                False
# TutorialBenchmarkData_storage_library_098                False
# TutorialBenchmarkData_storage_library_099                False
#
#                                            MorganFP_MorganFP_6  \
# ID
# TutorialBenchmarkData_storage_library_000                 True
# TutorialBenchmarkData_storage_library_001                False
# TutorialBenchmarkData_storage_library_002                False
# TutorialBenchmarkData_storage_library_003                False
# TutorialBenchmarkData_storage_library_004                False
# ...                                                        ...
# TutorialBenchmarkData_storage_library_095                False
# TutorialBenchmarkData_storage_library_096                False
# TutorialBenchmarkData_storage_library_097                False
# TutorialBenchmarkData_storage_library_098                False
# TutorialBenchmarkData_storage_library_099                False
#
#                                            MorganFP_MorganFP_7  \
# ID
# TutorialBenchmarkData_storage_library_000                 True
# TutorialBenchmarkData_storage_library_001                False
# TutorialBenchmarkData_storage_library_002                False
# TutorialBenchmarkData_storage_library_003                False
# TutorialBenchmarkData_storage_library_004                False
# ...                                                        ...
# TutorialBenchmarkData_storage_library_095                False
# TutorialBenchmarkData_storage_library_096                False
# TutorialBenchmarkData_storage_library_097                False
# TutorialBenchmarkData_storage_library_098                 True
# TutorialBenchmarkData_storage_library_099                False
#
#                                            MorganFP_MorganFP_8  \
# ID
# TutorialBenchmarkData_storage_library_000                False
# TutorialBenchmarkData_storage_library_001                False
# TutorialBenchmarkData_storage_library_002                 True
# TutorialBenchmarkData_storage_library_003                False
# TutorialBenchmarkData_storage_library_004                False
# ...                                                        ...
# TutorialBenchmarkData_storage_library_095                False
# TutorialBenchmarkData_storage_library_096                False
# TutorialBenchmarkData_storage_library_097                False
# TutorialBenchmarkData_storage_library_098                 True
# TutorialBenchmarkData_storage_library_099                False
#
#                                            MorganFP_MorganFP_9  ...  \
# ID                                                              ...
# TutorialBenchmarkData_storage_library_000                False  ...
# TutorialBenchmarkData_storage_library_001                False  ...
# TutorialBenchmarkData_storage_library_002                False  ...
# TutorialBenchmarkData_storage_library_003                False  ...
# TutorialBenchmarkData_storage_library_004                False  ...
# ...                                                        ...  ...
# TutorialBenchmarkData_storage_library_095                False  ...
# TutorialBenchmarkData_storage_library_096                False  ...
# TutorialBenchmarkData_storage_library_097                False  ...
# TutorialBenchmarkData_storage_library_098                False  ...
# TutorialBenchmarkData_storage_library_099                False  ...
#
#                                            RDkit_fr_sulfonamd  \
# ID
# TutorialBenchmarkData_storage_library_000                 0.0
# TutorialBenchmarkData_storage_library_001                 0.0
# TutorialBenchmarkData_storage_library_002                 0.0
# TutorialBenchmarkData_storage_library_003                 0.0
# TutorialBenchmarkData_storage_library_004                 0.0
# ...                                                       ...
# TutorialBenchmarkData_storage_library_095                 0.0
# TutorialBenchmarkData_storage_library_096                 0.0
# TutorialBenchmarkData_storage_library_097                 0.0
# TutorialBenchmarkData_storage_library_098                 0.0
# TutorialBenchmarkData_storage_library_099                 0.0
#
#                                            RDkit_fr_sulfone  \
# ID
# TutorialBenchmarkData_storage_library_000               0.0
# TutorialBenchmarkData_storage_library_001               0.0
# TutorialBenchmarkData_storage_library_002               0.0
# TutorialBenchmarkData_storage_library_003               0.0
# TutorialBenchmarkData_storage_library_004               0.0
# ...                                                     ...
# TutorialBenchmarkData_storage_library_095               0.0
# TutorialBenchmarkData_storage_library_096               0.0
# TutorialBenchmarkData_storage_library_097               0.0
# TutorialBenchmarkData_storage_library_098               1.0
# TutorialBenchmarkData_storage_library_099               0.0
#
#                                            RDkit_fr_term_acetylene  \
# ID
# TutorialBenchmarkData_storage_library_000                      0.0
# TutorialBenchmarkData_storage_library_001                      0.0
# TutorialBenchmarkData_storage_library_002                      0.0
# TutorialBenchmarkData_storage_library_003                      0.0
# TutorialBenchmarkData_storage_library_004                      0.0
# ...                                                            ...
# TutorialBenchmarkData_storage_library_095                      0.0
# TutorialBenchmarkData_storage_library_096                      0.0
# TutorialBenchmarkData_storage_library_097                      0.0
# TutorialBenchmarkData_storage_library_098                      0.0
# TutorialBenchmarkData_storage_library_099                      0.0
#
#                                            RDkit_fr_tetrazole  \
# ID
# TutorialBenchmarkData_storage_library_000                 0.0
# TutorialBenchmarkData_storage_library_001                 0.0
# TutorialBenchmarkData_storage_library_002                 0.0
# TutorialBenchmarkData_storage_library_003                 0.0
# TutorialBenchmarkData_storage_library_004                 0.0
# ...                                                       ...
# TutorialBenchmarkData_storage_library_095                 0.0
# TutorialBenchmarkData_storage_library_096                 0.0
# TutorialBenchmarkData_storage_library_097                 0.0
# TutorialBenchmarkData_storage_library_098                 0.0
# TutorialBenchmarkData_storage_library_099                 0.0
#
#                                            RDkit_fr_thiazole  \
# ID
# TutorialBenchmarkData_storage_library_000                0.0
# TutorialBenchmarkData_storage_library_001                0.0
# TutorialBenchmarkData_storage_library_002                0.0
# TutorialBenchmarkData_storage_library_003                0.0
# TutorialBenchmarkData_storage_library_004                1.0
# ...                                                      ...
# TutorialBenchmarkData_storage_library_095                0.0
# TutorialBenchmarkData_storage_library_096                0.0
# TutorialBenchmarkData_storage_library_097                1.0
# TutorialBenchmarkData_storage_library_098                0.0
# TutorialBenchmarkData_storage_library_099                0.0
#
#                                            RDkit_fr_thiocyan  \
# ID
# TutorialBenchmarkData_storage_library_000                0.0
# TutorialBenchmarkData_storage_library_001                0.0
# TutorialBenchmarkData_storage_library_002                0.0
# TutorialBenchmarkData_storage_library_003                0.0
# TutorialBenchmarkData_storage_library_004                0.0
# ...                                                      ...
# TutorialBenchmarkData_storage_library_095                0.0
# TutorialBenchmarkData_storage_library_096                0.0
# TutorialBenchmarkData_storage_library_097                0.0
# TutorialBenchmarkData_storage_library_098                0.0
# TutorialBenchmarkData_storage_library_099                0.0
#
#                                            RDkit_fr_thiophene  \
# ID
# TutorialBenchmarkData_storage_library_000                 0.0
# TutorialBenchmarkData_storage_library_001                 0.0
# TutorialBenchmarkData_storage_library_002                 0.0
# TutorialBenchmarkData_storage_library_003                 0.0
# TutorialBenchmarkData_storage_library_004                 0.0
# ...                                                       ...
# TutorialBenchmarkData_storage_library_095                 0.0
# TutorialBenchmarkData_storage_library_096                 0.0
# TutorialBenchmarkData_storage_library_097                 0.0
# TutorialBenchmarkData_storage_library_098                 0.0
# TutorialBenchmarkData_storage_library_099                 0.0
#
#                                            RDkit_fr_unbrch_alkane  \
# ID
# TutorialBenchmarkData_storage_library_000                     0.0
# TutorialBenchmarkData_storage_library_001                     0.0
# TutorialBenchmarkData_storage_library_002                     0.0
# TutorialBenchmarkData_storage_library_003                     0.0
# TutorialBenchmarkData_storage_library_004                     0.0
# ...                                                           ...
# TutorialBenchmarkData_storage_library_095                     0.0
# TutorialBenchmarkData_storage_library_096                     0.0
# TutorialBenchmarkData_storage_library_097                     0.0
# TutorialBenchmarkData_storage_library_098                     0.0
# TutorialBenchmarkData_storage_library_099                     0.0
#
#                                            RDkit_fr_urea  RDkit_qed
# ID
# TutorialBenchmarkData_storage_library_000            0.0   0.781396
# TutorialBenchmarkData_storage_library_001            0.0   0.736392
# TutorialBenchmarkData_storage_library_002            0.0   0.534122
# TutorialBenchmarkData_storage_library_003            0.0   0.733913
# TutorialBenchmarkData_storage_library_004            0.0   0.660116
# ...                                                  ...        ...
# TutorialBenchmarkData_storage_library_095            0.0   0.768685
# TutorialBenchmarkData_storage_library_096            0.0   0.683816
# TutorialBenchmarkData_storage_library_097            0.0   0.699868
# TutorialBenchmarkData_storage_library_098            0.0   0.585306
# TutorialBenchmarkData_storage_library_099            0.0   0.780763
#
# [100 rows x 466 columns]

# %% [markdown]
# It should be noted that the code above does not recalculate the descriptors, but rather reloads the data set saved here:

# %%
replica.ds.path
# Out:
# '/zfsdata/data/helle/01_MainProjects/03_QSPRpred/Scripts/QSPRpred/tutorials/tutorial_output/benchmarking/data/TutorialBenchmarkData_MorganFP_RDkit'

# %%
for assessor in replica.assessors:
    split = assessor.split  # get the split that was used in the assessor
    print(split.__class__.__name__)

    # reproduce the data preparation
    X_train, y_train, X_test, y_test = next(
        replica.pipeline.applyOnDataSet(replica.ds, split=split, fit=False))
    print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)

# %%
# initialize model with the prepared data
replica.initModel()
replica.model.alg

# %%
# run assesments
replica.runAssessment()

# %% [markdown]
# To results are saved withing the replica too:

# %%
replica.results
# Out:
#                          Assessor          ScoreFunc     Score  \
# 0             randomsplit_roc_auc      roc_auc_score  0.521978
# 0   randomsplit_matthews_corrcoef  matthews_corrcoef  0.104828
# 0            clustersplit_roc_auc      roc_auc_score  0.625000
# 0  clustersplit_matthews_corrcoef  matthews_corrcoef  0.123091
#
#        TargetProperty   TargetTask
# 0  pchembl_value_Mean  SINGLECLASS
# 0  pchembl_value_Mean  SINGLECLASS
# 0  pchembl_value_Mean  SINGLECLASS
# 0  pchembl_value_Mean  SINGLECLASS

# %% [markdown]
# Since the random seed was fixed to the original value, we should get the same results as in the original run:

# %%
df_results.iloc[0, :].Score, df_results.iloc[1, :].Score, df_results.iloc[2, :].Score, \
    df_results.iloc[3, :].Score

# %% [markdown]
# In order to get the complete report on the reproduced replica, the `replica.createReport()` method can be used:

# %%
replica.createReport()
# Out:
#                          Assessor          ScoreFunc     Score  \
# 0             randomsplit_roc_auc      roc_auc_score  0.521978
# 0   randomsplit_matthews_corrcoef  matthews_corrcoef  0.104828
# 0            clustersplit_roc_auc      roc_auc_score  0.625000
# 0  clustersplit_matthews_corrcoef  matthews_corrcoef  0.123091
#
#        TargetProperty   TargetTask  \
# 0  pchembl_value_Mean  SINGLECLASS
# 0  pchembl_value_Mean  SINGLECLASS
# 0  pchembl_value_Mean  SINGLECLASS
# 0  pchembl_value_Mean  SINGLECLASS
#
#                                            ModelFile   Algorithm  \
# 0  /zfsdata/data/helle/01_MainProjects/03_QSPRpre...  GaussianNB
# 0  /zfsdata/data/helle/01_MainProjects/03_QSPRpre...  GaussianNB
# 0  /zfsdata/data/helle/01_MainProjects/03_QSPRpre...  GaussianNB
# 0  /zfsdata/data/helle/01_MainProjects/03_QSPRpre...  GaussianNB
#
#   AlgorithmParams                    ReplicaID  \
# 0            null  TutorialBenchmark_478163327
# 0            null  TutorialBenchmark_478163327
# 0            null  TutorialBenchmark_478163327
# 0            null  TutorialBenchmark_478163327
#
#                                 DataSet  \
# 0  TutorialBenchmarkData_MorganFP_RDkit
# 0  TutorialBenchmarkData_MorganFP_RDkit
# 0  TutorialBenchmarkData_MorganFP_RDkit
# 0  TutorialBenchmarkData_MorganFP_RDkit
#
#                                          ReplicaFile
# 0  /zfsdata/data/helle/01_MainProjects/03_QSPRpre...
# 0  /zfsdata/data/helle/01_MainProjects/03_QSPRpre...
# 0  /zfsdata/data/helle/01_MainProjects/03_QSPRpre...
# 0  /zfsdata/data/helle/01_MainProjects/03_QSPRpre...

# %% [markdown]
# # Analyzing Results
#
# The resulting data frame contains concatenated reports from each replica. We can get detailed information about model parameters, data preparation settings, target properties and more. It is up to you to decide how to analyze the results. You can also override the `createReport()` method of the `Replica` class and change the `iterReplicas` of `BenchmarkRunner` to use your own implementation of various benchmarking steps.
#
# Here we just provide a few examples of retrieving various data to plot from the report we obtained here:

# %%
import pandas as pd

OUT_DIR = '../../tutorial_output/benchmarking'

# reload the data manually this time to avoid recalculating everything (the above code needs to be executed at least once)
df_results = pd.read_table(f'{OUT_DIR}/results.tsv')
df_results
# Out:
#                           Assessor          ScoreFunc     Score  \
# 0              randomsplit_roc_auc      roc_auc_score  0.521978
# 1    randomsplit_matthews_corrcoef  matthews_corrcoef  0.104828
# 2             clustersplit_roc_auc      roc_auc_score  0.625000
# 3   clustersplit_matthews_corrcoef  matthews_corrcoef  0.123091
# 4              randomsplit_roc_auc      roc_auc_score  0.757576
# ..                             ...                ...       ...
# 67  clustersplit_matthews_corrcoef  matthews_corrcoef  0.301511
# 68             randomsplit_roc_auc      roc_auc_score  0.802198
# 69   randomsplit_matthews_corrcoef  matthews_corrcoef  0.560440
# 70            clustersplit_roc_auc      roc_auc_score  0.388889
# 71  clustersplit_matthews_corrcoef  matthews_corrcoef -0.242320
#
#         TargetProperty   TargetTask  \
# 0   pchembl_value_Mean  SINGLECLASS
# 1   pchembl_value_Mean  SINGLECLASS
# 2   pchembl_value_Mean  SINGLECLASS
# 3   pchembl_value_Mean  SINGLECLASS
# 4   pchembl_value_Mean  SINGLECLASS
# ..                 ...          ...
# 67  pchembl_value_Mean  SINGLECLASS
# 68  pchembl_value_Mean  SINGLECLASS
# 69  pchembl_value_Mean  SINGLECLASS
# 70  pchembl_value_Mean  SINGLECLASS
# 71  pchembl_value_Mean  SINGLECLASS
#
#                                             ModelFile             Algorithm  \
# 0   /zfsdata/data/helle/01_MainProjects/03_QSPRpre...            GaussianNB
# 1   /zfsdata/data/helle/01_MainProjects/03_QSPRpre...            GaussianNB
# 2   /zfsdata/data/helle/01_MainProjects/03_QSPRpre...            GaussianNB
# 3   /zfsdata/data/helle/01_MainProjects/03_QSPRpre...            GaussianNB
# 4   /zfsdata/data/helle/01_MainProjects/03_QSPRpre...            GaussianNB
# ..                                                ...                   ...
# 67  /zfsdata/data/helle/01_MainProjects/03_QSPRpre...            GaussianNB
# 68  /zfsdata/data/helle/01_MainProjects/03_QSPRpre...  ExtraTreesClassifier
# 69  /zfsdata/data/helle/01_MainProjects/03_QSPRpre...  ExtraTreesClassifier
# 70  /zfsdata/data/helle/01_MainProjects/03_QSPRpre...  ExtraTreesClassifier
# 71  /zfsdata/data/helle/01_MainProjects/03_QSPRpre...  ExtraTreesClassifier
#
#                 AlgorithmParams                     ReplicaID  \
# 0                           NaN   TutorialBenchmark_478163327
# 1                           NaN   TutorialBenchmark_478163327
# 2                           NaN   TutorialBenchmark_478163327
# 3                           NaN   TutorialBenchmark_478163327
# 4                           NaN  TutorialBenchmark_1181241943
# ..                          ...                           ...
# 67                          NaN  TutorialBenchmark_1812140441
# 68  {"random_state": 946785248}   TutorialBenchmark_946785248
# 69  {"random_state": 946785248}   TutorialBenchmark_946785248
# 70  {"random_state": 946785248}   TutorialBenchmark_946785248
# 71  {"random_state": 946785248}   TutorialBenchmark_946785248
#
#                                  DataSet  \
# 0   TutorialBenchmarkData_MorganFP_RDkit
# 1   TutorialBenchmarkData_MorganFP_RDkit
# 2   TutorialBenchmarkData_MorganFP_RDkit
# 3   TutorialBenchmarkData_MorganFP_RDkit
# 4         TutorialBenchmarkData_MorganFP
# ..                                   ...
# 67        TutorialBenchmarkData_MorganFP
# 68           TutorialBenchmarkData_RDkit
# 69           TutorialBenchmarkData_RDkit
# 70           TutorialBenchmarkData_RDkit
# 71           TutorialBenchmarkData_RDkit
#
#                                           ReplicaFile
# 0   /zfsdata/data/helle/01_MainProjects/03_QSPRpre...
# 1   /zfsdata/data/helle/01_MainProjects/03_QSPRpre...
# 2   /zfsdata/data/helle/01_MainProjects/03_QSPRpre...
# 3   /zfsdata/data/helle/01_MainProjects/03_QSPRpre...
# 4   /zfsdata/data/helle/01_MainProjects/03_QSPRpre...
# ..                                                ...
# 67  /zfsdata/data/helle/01_MainProjects/03_QSPRpre...
# 68  /zfsdata/data/helle/01_MainProjects/03_QSPRpre...
# 69  /zfsdata/data/helle/01_MainProjects/03_QSPRpre...
# 70  /zfsdata/data/helle/01_MainProjects/03_QSPRpre...
# 71  /zfsdata/data/helle/01_MainProjects/03_QSPRpre...
#
# [72 rows x 11 columns]

# %%
# we used different models, descriptors and splits
# probably makes sense to first get info about splits
# not in the original report, but...

from qsprpred.benchmarks import Replica


def get_split_info(replica_file, assessor_name):
    replica = Replica.fromFile(replica_file)
    for assessor in replica.assessors:
        if assessor.name == assessor_name:
            return assessor.split.__class__.__name__


df_results['Split'] = df_results.apply(
    lambda row: get_split_info(row['ReplicaFile'], row['Assessor']), axis=1)
df_results

# %%
# we have info about data set, which is ok to describe our combination of descriptors
df_results['Descriptors'] = df_results['DataSet'].apply(
    lambda x: "_".join(x.split('_')[1:]))
df_results['Descriptors']

# %%
import seaborn as sns
from matplotlib import pyplot as plt


# we can now create a couple informative box plots
# check the output directory to see the figures

def make_box_plot(data, x, y, hue, plot_name="boxplot"):
    # generate one plot for each metric
    for score_func in df_results.ScoreFunc.unique():
        df_ind = df_results.loc[(df_results.ScoreFunc == score_func)]
        plt.ylim([0, 1])
        plt.title(score_func)
        sns.boxplot(
            data=df_ind,
            x=x,
            y=y,
            hue=hue,
        )
        plt.savefig(f"{OUT_DIR}/{plot_name}_{score_func}_{x}_{y}_{hue}.png")
        plt.clf()
        plt.close()


# comparison of descriptors and their influence on each model's performance in cluster split
make_box_plot(
    df_results[df_results.Split == "ClusterSplit"],
    x="Algorithm",
    y="Score",
    hue="Descriptors",
    plot_name="ClusterSplit"
)
# comparison of performance for different splitting strategies for each model (cluster split clearly more difficult)
# TODO: we could follow this up with a tutorial to integrate the AVE bias (still in qsp-bench, the tools.py script)
make_box_plot(
    df_results[df_results.Algorithm == "GaussianNB"],
    x="Split",
    y="Score",
    hue="Descriptors",
    plot_name="GaussianNB"
)
make_box_plot(
    df_results[df_results.Algorithm == "ExtraTreesClassifier"],
    x="Split",
    y="Score",
    hue="Descriptors",
    plot_name="ExtraTreesClassifier"
)
